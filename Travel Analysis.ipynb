# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

travels = pd.read_csv('customertravel.csv')

# %%
travels.head()
# Out:
#    Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0   34            No     Middle Income              6
# 1   34           Yes        Low Income              5
# 2   37            No     Middle Income              3
# 3   30            No     Middle Income              2
# 4   30            No        Low Income              1
#
#   AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                         No              Yes       0
# 1                        Yes               No       1
# 2                        Yes               No       0
# 3                         No               No       0
# 4                         No               No       0

# %%
travels.tail()
# Out:
#      Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 949   31           Yes        Low Income              1
# 950   30            No     Middle Income              5
# 951   37            No     Middle Income              4
# 952   30            No        Low Income              1
# 953   31           Yes       High Income              1
#
#     AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 949                         No               No       0
# 950                         No              Yes       0
# 951                         No               No       0
# 952                        Yes              Yes       0
# 953                         No               No       0

# %%
sns.pairplot(travels)

# %%
plt.figure(figsize = (20,8))
sns.heatmap(travels.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Issue where there's too much categorical data that I can't analyze through heatmaps and pairplots, so time to get_dummies.

# %%
travels2 = pd.get_dummies(data=travels, drop_first=True)
travels2
# Out:
#      Age  ServicesOpted  Target  FrequentFlyer_No Record  FrequentFlyer_Yes  \
# 0     34              6       0                        0                  0
# 1     34              5       1                        0                  1
# 2     37              3       0                        0                  0
# 3     30              2       0                        0                  0
# 4     30              1       0                        0                  0
# ..   ...            ...     ...                      ...                ...
# 949   31              1       0                        0                  1
# 950   30              5       0                        0                  0
# 951   37              4       0                        0                  0
# 952   30              1       0                        0                  0
# 953   31              1       0                        0                  1
#
#      AnnualIncomeClass_Low Income  AnnualIncomeClass_Middle Income  \
# 0                               0                                1
# 1                               1                                0
# 2                               0                                1
# 3                               0                                1
# 4                               1                                0
# ..                            ...                              ...
# 949                             1                                0
# 950                             0                                1
# 951                             0                                1
# 952                             1                                0
# 953                             0                                0
#
#      AccountSyncedToSocialMedia_Yes  BookedHotelOrNot_Yes
# 0                                 0                     1
# 1                                 1                     0
# 2                                 1                     0
# 3                                 0                     0
# 4                                 0                     0
# ..                              ...                   ...
# 949                               0                     0
# 950                               0                     1
# 951                               0                     0
# 952                               1                     1
# 953                               0                     0
#
# [954 rows x 9 columns]

# %%
#now for my favorite part, the heatmap after all the categoricals have been turned into numericals.

plt.figure(figsize = (20,8))
sns.heatmap(travels2.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#Of our correlations we can see that the income brackets, frequent flyers, and social media sync'd columns have the strongest with other data. 
#Surprisingly, age seems to have very little correlation with anything.
